# %% [markdown]
# ### Peer review team
#
# - Peer review by: Group B
# - Names of team members that participated in this review: Niels-Janos Simmet & Raghid Allaham
#
# ### Goal of the project
#
# 1) Predict if two peopol of opposite sex are having a "match" based on certin attributes.
# 2) Find out what are the most importent attributes to get a match in opposite sex speed dating.
# 3) Proof of correctness of the following hypotheses:
# -   Survey participants who both have the specific characteristics samerace and opposite gender tend to achieve more matches
# -   Survey participants with a higher income tend to achieve more matches than survey participants with a lower income
# -   Achieving matches because of having the same specific characteristics occur in both sexes
# -   Three weeks after the event, males called women more often
#
# ### Data
#
# Fisman et al. conducted a survey regarding speed dating habits and collected 8,000 observations.
# These data were collected from participants in experimental speed dating events held in 2002-2004. In these events, participants had a four-minute "first date" with each other participant of the opposite sex. At the end of the four minutes, participants were asked if they would like to see their date again. They were also asked to rate their date on some characteristics.
#
# Data: https://perso.telecom-paristech.fr/eagan/class/igr204/datasets/SpeedDating.csv
#
#
# ### Approach, tools and methods
#
# - Data is imported and corrected.
#  A subset of the data is made by only selecting variables that are known before a play.
#  The variables are explained within a data dictionary, and some data exploration is made.
#  The relation and correlation from the subset with the response variable is displayed.
#
# - The tools used are well known data manipulation and machine learning libraries such as
# pandas, numpy, altair, matplotlib and sklearn
#
# - A pairplot matrix and correlation matrix is made to show relation and correlation of variables.
#  The data is split into training and test set for the models.
#  The regression is modelled by using Linear, Lasso and KNN Regression algorithms.
#  These are then compared to a model that always predicts the mean of yards gained (similar to a naive predictor that sets a baseline).
#
# ### Lack of clarity
#
# - No clear deffintion, what does "mach" mean?
#
# - The mean question Task could be clearer (Prediction of "mach" depenting on some atributs).
#
# ### Possible improvements
#
# - In addition, you could have separated the data by gender to see how differently genders react to characteristics. (example hypothesis: men don't like it when a woman is ambitious.) plot a correlation matrix per gender and examine which attributes are most important to a woman and which attributes are important to a man. Doing so would answer the research question: "Do these specific characteristics occur in both sexes?".
#
# - You should show the original dataset with its original features, this way the reader can understand why You chose Your subset of variables.
#
# - In your models, you could try to include more / other variables and see if the performance changes.
#  This could lead to a different conclusion or use backward or forward selection to chose the variables.
#
# ### Presentation
#
# - The most interesting part is how the research question can be answered.
#  Is something similar already used by Dating Apps? if yes, what kind of data do they use?
#
# - Also what could be done in order to improve the models further, what the next steps for a follow-up project could be.
#
# ### Organization
#
# - The only improvements for code organizations is to consistently use comments for every block of code.
#  Other than that the code is clean and easy to read.
#
# - The data is not clearly located within the data folder.
# The cleaned dataset is found within the raw folder together with the original dataset.
# Is the data_cleaned_2021.csv the original dataset?
#
# - There is no model being saved for the Lasso Regression.
# The linear regression and KNN Regression Model file have the same name.
#
# ### Further comments
#
# - Do you have additional content for the appendix?
#  Because there is none in the notebook yet.
#
# - If you want to put the icing on the cake for interactive graphs you could use tooltips:
# alt.Chart(df_tmp).mark_bar().encode(
#     x=alt.X("yards_gained"),
#     y=alt.Y('count()'),
#     tooltip = ['yards_gained']
# ).interactive()
